# %%
from src.config import AUTH_TOKEN_HF
AUTH_TOKEN_HF

# %%
import warnings
warnings.filterwarnings("ignore")

import torch

print(f"PyTorch:        {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Nº GPUs:        {torch.cuda.device_count()}")
if torch.cuda.is_available():
    print(f"GPU:            {torch.cuda.get_device_name(0)}")

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device:  {device}")

# %%
from src.utils import DATA_EXTRACTED_DIR
print(DATA_EXTRACTED_DIR)

# %%
import os
X = df_results.drop(columns=['label'])
y = df_results['label'].values

# %%
from src.utils_plot import PCA_plot, tsne_plot
PCA_plot(X, y, title="Evaluation Results PCA")
tsne_plot(X, y, title="Evaluation Results t-SNE")

# %%
X = df_embeddings

# %%
PCA_plot(X, y, title="Evaluation Results PCA")
tsne_plot(X, y, title="Evaluation Results t-SNE")

# %%
X = df_embeddings.join(df_results)
X = X.drop(columns=['label'])
y = df_results['label'].values

# %%
PCA_plot(X, y, title="Evaluation Results PCA")
tsne_plot(X, y, title="Evaluation Results t-SNE")

# %%
X2 = X.join(df_features)
y = df_results['label'].values

# %%
PCA_plot(X2, y, title="Evaluation Results PCA")
tsne_plot(X2, y, title="Evaluation Results t-SNE")
